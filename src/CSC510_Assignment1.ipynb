# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Carpet and Hardwood").config("spark.some.config.option", "some-value").getOrCreate()
carpet = spark.read.csv("../data/carpet.csv")
hardwood = spark.read.csv("../data/hardwood.csv")

# %% [markdown]
# **Statistical Information**

# %%
n_carpet = len(carpet.columns) * carpet.count()
print("Number of observations in carpet.csv:", n_carpet)
n_hardwood = len(hardwood.columns) * hardwood.count()
print("Number of observations in hardwood.csv:", n_hardwood)
# Out:
# Number of observations in carpet.csv: 65536
# Number of observations in hardwood.csv: 65536

# %%
for col in carpet.columns:
    carpet.describe([col]).show()
# Out:
# +-------+------------------+
# |summary|               _c0|
# +-------+------------------+
# |  count|              1024|
# |   mean| 151.8504160156249|
# | stddev|22.671127881603628|
# |    min|            100.21|
# |    max|            99.996|
# +-------+------------------+
#
# +-------+------------------+
# |summary|               _c1|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.28129980468736|
# | stddev|22.043465914193835|
# |    min|            100.01|
# |    max|            99.782|
# +-------+------------------+
#
# +-------+------------------+
# |summary|               _c2|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.28350976562498|
# | stddev| 21.64234771849469|
# |    min|            100.21|
# |    max|            99.004|
# +-------+------------------+
#
# +-------+------------------+
# |summary|               _c3|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.91973242187484|
# | stddev|21.715600769419606|
# |    min|            101.02|
# |    max|            99.792|
# +-------+------------------+
#
# +-------+------------------+
# |summary|               _c4|
# +-------+------------------+
# |  count|              1024|
# |   mean| 152.5990107421876|
# | stddev|22.467179732377677|
# |    min|            100.37|
# |    max|             99.81|
# +-------+------------------+
#
# +-------+------------------+
# |summary|               _c5|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.82919921874984|
# | stddev| 22.33678920082103|
# |    min|            100.37|
# |    max|            97.818|
# +-------+------------------+
#
# +-------+------------------+
# |summary|               _c6|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.29369042968744|
# | stddev| 22.02894909046214|
# |    min|            100.22|
# |    max|            99.909|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|              _c7|
# +-------+-----------------+
# |  count|             1024|
# |   mean|151.9605263671876|
# | stddev|22.66004905036816|
# |    min|           100.12|
# |    max|           99.158|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|               _c8|
# +-------+------------------+
# |  count|              1024|
# |   mean| 152.1237177734376|
# | stddev|22.858321647979697|
# |    min|            101.58|
# |    max|            99.731|
# +-------+------------------+
#
# +-------+------------------+
# |summary|               _c9|
# +-------+------------------+
# |  count|              1024|
# |   mean|  152.248083984375|
# | stddev|22.513211154249714|
# |    min|               100|
# |    max|            99.406|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c10|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.23666699218748|
# | stddev|21.963217990539206|
# |    min|            101.16|
# |    max|            99.919|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c11|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.78264550781273|
# | stddev|22.374918850583658|
# |    min|            100.83|
# |    max|            98.728|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c12|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.58238281249984|
# | stddev|22.724859138916862|
# |    min|            100.68|
# |    max|            99.347|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c13|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.75199804687492|
# | stddev| 22.61340784433667|
# |    min|            100.34|
# |    max|            99.603|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c14|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.28278906250014|
# | stddev|22.521353488250945|
# |    min|            100.71|
# |    max|            99.457|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c15|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.62381933593758|
# | stddev|22.632738328879167|
# |    min|            100.32|
# |    max|            99.032|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c16|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.63195214843768|
# | stddev| 21.57595160239816|
# |    min|            100.46|
# |    max|             98.92|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|             _c17|
# +-------+-----------------+
# |  count|             1024|
# |   mean|152.0138759765623|
# | stddev|22.35459201575502|
# |    min|           100.99|
# |    max|           98.608|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|              _c18|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.50182324218767|
# | stddev| 22.11359335159825|
# |    min|            101.29|
# |    max|            98.676|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c19|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.40976660156255|
# | stddev|22.391987872428857|
# |    min|            101.18|
# |    max|            99.073|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c20|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.36224121093755|
# | stddev| 22.70610876376672|
# |    min|            100.49|
# |    max|            99.849|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c21|
# +-------+------------------+
# |  count|              1024|
# |   mean| 152.9665947265625|
# | stddev|22.570411841584562|
# |    min|            100.65|
# |    max|            99.765|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c22|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.07263769531238|
# | stddev| 22.71535541446922|
# |    min|            102.37|
# |    max|            99.885|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c23|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.69874999999993|
# | stddev|22.465243976088516|
# |    min|            100.64|
# |    max|            99.868|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c24|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.68141113281226|
# | stddev| 22.73762533173181|
# |    min|            100.01|
# |    max|            99.591|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|             _c25|
# +-------+-----------------+
# |  count|             1024|
# |   mean|152.0255126953125|
# | stddev|22.19795019527216|
# |    min|           100.19|
# |    max|           98.211|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|              _c26|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.20490039062489|
# | stddev|22.132857515080005|
# |    min|            100.02|
# |    max|            99.977|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c27|
# +-------+------------------+
# |  count|              1024|
# |   mean|150.83440820312478|
# | stddev| 21.90828035173138|
# |    min|            100.32|
# |    max|            99.693|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c28|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.66206445312534|
# | stddev| 22.38449168591725|
# |    min|            101.15|
# |    max|            99.844|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c29|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.15678710937473|
# | stddev|22.686676968057082|
# |    min|            100.05|
# |    max|            99.512|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c30|
# +-------+------------------+
# |  count|              1024|
# |   mean| 151.9741367187501|
# | stddev|22.753909756030733|
# |    min|            100.31|
# |    max|            98.705|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c31|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.56723925781245|
# | stddev| 22.69147180180567|
# |    min|            100.19|
# |    max|            98.055|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c32|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.04717675781248|
# | stddev|22.869231645204852|
# |    min|            100.41|
# |    max|            99.244|
# +-------+------------------+
# +-------+------------------+
# |summary|              _c33|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.25547167968753|
# | stddev|22.575592434496684|
# |    min|            100.81|
# |    max|            99.453|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c34|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.30748242187508|
# | stddev|22.787499393991578|
# |    min|            101.29|
# |    max|            96.636|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c35|
# +-------+------------------+
# |  count|              1024|
# |   mean|150.19197167968738|
# | stddev|21.850658237895374|
# |    min|            100.28|
# |    max|            99.511|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c36|
# +-------+------------------+
# |  count|              1024|
# |   mean| 150.9789550781246|
# | stddev|22.379040656989922|
# |    min|            100.49|
# |    max|            99.859|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c37|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.66835156250008|
# | stddev| 23.02735120699726|
# |    min|            100.77|
# |    max|            99.554|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c38|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.73309570312466|
# | stddev|23.382288685387163|
# |    min|            100.17|
# |    max|            99.813|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c39|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.64523242187514|
# | stddev|23.021127602075662|
# |    min|            100.22|
# |    max|            99.043|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c40|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.26546386718746|
# | stddev|23.220111379822495|
# |    min|            100.03|
# |    max|            99.359|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c41|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.39843750000014|
# | stddev|22.755880131885355|
# |    min|            101.49|
# |    max|             99.65|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c42|
# +-------+------------------+
# |  count|              1024|
# |   mean| 151.1325292968749|
# | stddev|22.795536681323416|
# |    min|            100.96|
# |    max|            99.955|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c43|
# +-------+------------------+
# |  count|              1024|
# |   mean|150.90535644531244|
# | stddev|23.163811504506835|
# |    min|            100.55|
# |    max|            99.719|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c44|
# +-------+------------------+
# |  count|              1024|
# |   mean|150.50945898437507|
# | stddev| 22.94973130905135|
# |    min|            101.38|
# |    max|            99.907|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c45|
# +-------+------------------+
# |  count|              1024|
# |   mean|150.90281835937506|
# | stddev|22.988003966628142|
# |    min|            100.07|
# |    max|            99.832|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c46|
# +-------+------------------+
# |  count|              1024|
# |   mean|    151.7819765625|
# | stddev|23.070550465802707|
# |    min|            100.74|
# |    max|            98.923|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c47|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.85589843749983|
# | stddev|23.115496895729876|
# |    min|            100.11|
# |    max|            99.772|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c48|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.47591406249984|
# | stddev|  22.0415721664396|
# |    min|            100.27|
# |    max|            98.372|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c49|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.10823046874995|
# | stddev|22.603293752871526|
# |    min|            100.81|
# |    max|            99.616|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c50|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.46537500000002|
# | stddev|23.083369866231223|
# |    min|            101.12|
# |    max|            99.968|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c51|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.99030859375003|
# | stddev|23.334017245007498|
# |    min|            100.35|
# |    max|            99.351|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c52|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.39927441406232|
# | stddev|23.030062361642077|
# |    min|            100.46|
# |    max|            99.643|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c53|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.94729785156272|
# | stddev|  22.8041131033474|
# |    min|            101.07|
# |    max|            98.758|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c54|
# +-------+------------------+
# |  count|              1024|
# |   mean| 152.4150361328128|
# | stddev|22.928062101193632|
# |    min|            101.62|
# |    max|            99.633|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c55|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.17765234375003|
# | stddev|22.643368747922292|
# |    min|            100.34|
# |    max|            99.932|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c56|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.54137695312497|
# | stddev|22.319997056379073|
# |    min|            100.04|
# |    max|            99.781|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c57|
# +-------+------------------+
# |  count|              1024|
# |   mean|150.68695800781245|
# | stddev|22.579196776340545|
# |    min|            100.18|
# |    max|            99.489|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c58|
# +-------+------------------+
# |  count|              1024|
# |   mean|150.89364746093747|
# | stddev|22.699180244256095|
# |    min|            100.35|
# |    max|            99.038|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|             _c59|
# +-------+-----------------+
# |  count|             1024|
# |   mean|151.4153955078125|
# | stddev|23.34175219782217|
# |    min|           100.42|
# |    max|           99.645|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|              _c60|
# +-------+------------------+
# |  count|              1024|
# |   mean|151.73828613281248|
# | stddev|22.737060261056612|
# |    min|            101.18|
# |    max|            99.852|
# +-------+------------------+
#
# +-------+------------------+
# |summary|              _c61|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.11242285156277|
# | stddev| 22.50129676658248|
# |    min|            100.31|
# |    max|            98.518|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|             _c62|
# +-------+-----------------+
# |  count|             1024|
# |   mean|152.0208759765624|
# | stddev|22.58383897718583|
# |    min|            100.9|
# |    max|           99.208|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|              _c63|
# +-------+------------------+
# |  count|              1024|
# |   mean|152.20948925781252|
# | stddev| 22.56167295762885|
# |    min|            101.87|
# |    max|             99.17|
# +-------+------------------+

# %%
carpet_df = carpet.describe().toPandas().set_index('summary').T
hardwood_df = hardwood.describe().toPandas().set_index('summary').T

# %%
carpet_df
# Out:
# summary count                mean              stddev     min     max
# _c0      1024   151.8504160156249  22.671127881603628  100.21  99.996
# _c1      1024  151.28129980468736  22.043465914193835  100.01  99.782
# _c2      1024  151.28350976562498   21.64234771849469  100.21  99.004
# _c3      1024  151.91973242187484  21.715600769419606  101.02  99.792
# _c4      1024   152.5990107421876  22.467179732377677  100.37   99.81
# _c5      1024  152.82919921874984   22.33678920082103  100.37  97.818
# _c6      1024  152.29369042968744   22.02894909046214  100.22  99.909
# _c7      1024   151.9605263671876   22.66004905036816  100.12  99.158
# _c8      1024   152.1237177734376  22.858321647979697  101.58  99.731
# _c9      1024    152.248083984375  22.513211154249714     100  99.406
# _c10     1024  151.23666699218748  21.963217990539206  101.16  99.919
# _c11     1024  151.78264550781273  22.374918850583658  100.83  98.728
# _c12     1024  152.58238281249984  22.724859138916862  100.68  99.347
# _c13     1024  152.75199804687492   22.61340784433667  100.34  99.603
# _c14     1024  152.28278906250014  22.521353488250945  100.71  99.457
# _c15     1024  151.62381933593758  22.632738328879167  100.32  99.032
# _c16     1024  151.63195214843768   21.57595160239816  100.46   98.92
# _c17     1024   152.0138759765623   22.35459201575502  100.99  98.608
# _c18     1024  151.50182324218767   22.11359335159825  101.29  98.676
# _c19     1024  151.40976660156255  22.391987872428857  101.18  99.073
# _c20     1024  152.36224121093755   22.70610876376672  100.49  99.849
# _c21     1024   152.9665947265625  22.570411841584562  100.65  99.765
# _c22     1024  152.07263769531238   22.71535541446922  102.37  99.885
# _c23     1024  151.69874999999993  22.465243976088516  100.64  99.868
# _c24     1024  151.68141113281226   22.73762533173181  100.01  99.591
# _c25     1024   152.0255126953125   22.19795019527216  100.19  98.211
# _c26     1024  151.20490039062489  22.132857515080005  100.02  99.977
# _c27     1024  150.83440820312478   21.90828035173138  100.32  99.693
